# %%
import numpy as np
import pandas as pd

# %%
food_info = pd.read_csv('food_info.csv')
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# ...

# %%
food_info.tail()
# Out:
#       NDB_No                   Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 8613   83110             MACKEREL SALTED      43.00         305        18.50
# 8614   90240  SCALLOP (BAY&SEA) CKD STMD      70.25         111        20.54
# 8615   90480                  SYRUP CANE      26.00         269         0.00
# 8616   90560                   SNAIL RAW      79.20          90        16.10
# 8617   93600            TURTLE GREEN RAW      78.50          89        19.80
#
#       Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 8613          25.10    13.40            0.00           0.0            0.0
# 8614           0.84     2.97            5.41           0.0            0.0
# 8615           0.00     0.86           73.14           0.0           73.2
# 8616           1.40     1.30            2.00           0.0            0.0
# 8617           0.50     1.20            0.00           0.0            0.0
#
# ...

# %%
food_info.ix[[0,2,4,5]]
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#    NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001      BUTTER WITH SALT      15.87         717         0.85
# 2    1003  BUTTER OIL ANHYDROUS       0.24         876         0.28
# 4    1005          CHEESE BRICK      41.11         371        23.24
# 5    1006           CHEESE BRIE      48.42         334        20.75
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# ...

# %%
food_info[[0,3,4]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-a4a3c3927624> in <module>()
# ----> 1 food_info[[0,3,4]]
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# ...

# %%
food_info.NDB_No
# Out:
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010
# 10       1011
# 11       1012
# 12       1013
# 13       1014
# 14       1015
# 15       1016
# 16       1017
# 17       1018
# 18       1019
# 19       1020
# 20       1021
# 21       1022
# 22       1023
# 23       1024
# 24       1025
# 25       1026
# 26       1027
# 27       1028
# 28       1029
# 29       1030
#         ...
# 8588    43544
# 8589    43546
# 8590    43550
# 8591    43566
# 8592    43570
# 8593    43572
# 8594    43585
# 8595    43589
# 8596    43595
# 8597    43597
# 8598    43598
# 8599    44005
# 8600    44018
# 8601    44048
# 8602    44055
# 8603    44061
# 8604    44074
# 8605    44110
# 8606    44158
# 8607    44203
# 8608    44258
# 8609    44259
# 8610    44260
# 8611    48052
# 8612    80200
# 8613    83110
# 8614    90240
# 8615    90480
# 8616    90560
# 8617    93600
# ...

# %%
food_info['NDB_No']
# Out:
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010
# 10       1011
# 11       1012
# 12       1013
# 13       1014
# 14       1015
# 15       1016
# 16       1017
# 17       1018
# 18       1019
# 19       1020
# 20       1021
# 21       1022
# 22       1023
# 23       1024
# 24       1025
# 25       1026
# 26       1027
# 27       1028
# 28       1029
# 29       1030
#         ...
# 8588    43544
# 8589    43546
# 8590    43550
# 8591    43566
# 8592    43570
# 8593    43572
# 8594    43585
# 8595    43589
# 8596    43595
# 8597    43597
# 8598    43598
# 8599    44005
# 8600    44018
# 8601    44048
# 8602    44055
# 8603    44061
# 8604    44074
# 8605    44110
# 8606    44158
# 8607    44203
# 8608    44258
# 8609    44259
# 8610    44260
# 8611    48052
# 8612    80200
# 8613    83110
# 8614    90240
# 8615    90480
# 8616    90560
# 8617    93600
# ...

# %%
food_info.iloc[0]
# Out:
# NDB_No                         1001
# Shrt_Desc          BUTTER WITH SALT
# Water_(g)                     15.87
# Energ_Kcal                      717
# Protein_(g)                    0.85
# Lipid_Tot_(g)                 81.11
# Ash_(g)                        2.11
# Carbohydrt_(g)                 0.06
# Fiber_TD_(g)                      0
# Sugar_Tot_(g)                  0.06
# Calcium_(mg)                     24
# Iron_(mg)                      0.02
# Magnesium_(mg)                    2
# Phosphorus_(mg)                  24
# Potassium_(mg)                   24
# Sodium_(mg)                     643
# Zinc_(mg)                      0.09
# Copper_(mg)                       0
# Manganese_(mg)                    0
# Selenium_(mcg)                    1
# Vit_C_(mg)                        0
# Thiamin_(mg)                  0.005
# Riboflavin_(mg)               0.034
# Niacin_(mg)                   0.042
# Vit_B6_(mg)                   0.003
# Vit_B12_(mcg)                  0.17
# ...

# %%
food_info[['NDB_No','Water_(g)']]
# Out:
#       NDB_No  Water_(g)
# 0       1001      15.87
# 1       1002      15.87
# 2       1003       0.24
# 3       1004      42.41
# 4       1005      41.11
# 5       1006      48.42
# 6       1007      51.80
# 7       1008      39.28
# 8       1009      37.10
# 9       1010      37.65
# 10      1011      38.20
# 11      1012      79.79
# 12      1013      79.64
# 13      1014      81.01
# 14      1015      81.24
# 15      1016      82.48
# 16      1017      54.44
# 17      1018      41.56
# 18      1019      55.22
# 19      1020      37.92
# 20      1021      13.44
# 21      1022      41.46
# 22      1023      33.19
# 23      1024      48.42
# 24      1025      41.01
# 25      1026      50.01
# 26      1027      48.38
# 27      1028      53.78
# 28      1029      45.54
# 29      1030      41.77
# ...      ...        ...
# 8588   43544       2.00
# 8589   43546      76.70
# 8590   43550      83.10
# 8591   43566       1.30
# 8592   43570       5.00
# 8593   43572       2.80
# ...

# %%
food_info.shape
# Out:
# (8618, 36)

# %%
food_info.head(2)
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# 0       ...          2499.0      684.0        2.32        1.5      60.0
# 1       ...          2499.0      684.0        2.32        1.5      60.0
#
#    Vit_K_(mcg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# 0          7.0      51.368       21.021        3.043           215.0
# 1          7.0      50.489       23.426        3.012           219.0
#
# [2 rows x 36 columns]

# %%
food_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 36 columns):
# NDB_No             8618 non-null int64
# Shrt_Desc          8618 non-null object
# Water_(g)          8612 non-null float64
# Energ_Kcal         8618 non-null int64
# Protein_(g)        8618 non-null float64
# Lipid_Tot_(g)      8618 non-null float64
# Ash_(g)            8286 non-null float64
# Carbohydrt_(g)     8618 non-null float64
# Fiber_TD_(g)       7962 non-null float64
# Sugar_Tot_(g)      6679 non-null float64
# Calcium_(mg)       8264 non-null float64
# Iron_(mg)          8471 non-null float64
# Magnesium_(mg)     7936 non-null float64
# Phosphorus_(mg)    8046 non-null float64
# Potassium_(mg)     8208 non-null float64
# Sodium_(mg)        8535 non-null float64
# Zinc_(mg)          7917 non-null float64
# Copper_(mg)        7363 non-null float64
# Manganese_(mg)     6478 non-null float64
# Selenium_(mcg)     6868 non-null float64
# ...

# %%
oo = pd.read_csv('olympics.csv',skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
# City            29216 non-null object
# Edition         29216 non-null int64
# Sport           29216 non-null object
# Discipline      29216 non-null object
# Athlete         29216 non-null object
# NOC             29216 non-null object
# Gender          29216 non-null object
# Event           29216 non-null object
# Event_gender    29216 non-null object
# Medal           29216 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %%
oo.Edition.sort_values()
# Out:
# 0        1896
# 97       1896
# 98       1896
# 99       1896
# 100      1896
# 101      1896
# 102      1896
# 103      1896
# 104      1896
# 105      1896
# 106      1896
# 107      1896
# 108      1896
# 109      1896
# 110      1896
# 111      1896
# 96       1896
# 112      1896
# 95       1896
# 93       1896
# 78       1896
# 79       1896
# 80       1896
# 81       1896
# 82       1896
# 83       1896
# 84       1896
# 85       1896
# 86       1896
# 87       1896
#          ...
# 27872    2008
# 27871    2008
# 27870    2008
# 27869    2008
# 27868    2008
# 27867    2008
# 27866    2008
# 27865    2008
# 27864    2008
# 27863    2008
# 27862    2008
# 27861    2008
# 27860    2008
# 27843    2008
# 27859    2008
# 27857    2008
# 27856    2008
# 27855    2008
# 27854    2008
# 27853    2008
# 27852    2008
# 27851    2008
# 27850    2008
# 27849    2008
# 27848    2008
# 27847    2008
# 27846    2008
# 27845    2008
# 27858    2008
# 29215    2008
# ...

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# ...

# %%
food_info['Water_(g)'].sort_values()
# Out:
# 676       0.00
# 664       0.00
# 665       0.00
# 666       0.00
# 667       0.00
# 668       0.00
# 669       0.00
# 670       0.00
# 671       0.00
# 8599      0.00
# 673       0.00
# 675       0.00
# 6417      0.00
# 677       0.00
# 678       0.00
# 679       0.00
# 680       0.00
# 681       0.00
# 682       0.00
# 683       0.00
# 684       0.00
# 685       0.00
# 686       0.00
# 687       0.00
# 663       0.00
# 662       0.00
# 661       0.00
# 660       0.00
# 8177      0.00
# 8180      0.00
#          ...
# 4270     99.80
# 4411     99.85
# 4408     99.89
# 4205     99.90
# 4357     99.90
# 4369     99.90
# 4356     99.90
# 4347     99.90
# 4239     99.90
# 4203     99.93
# 4213     99.95
# 4204     99.95
# 4208     99.95
# 4374     99.96
# 4379     99.97
# 4407     99.97
# 4373     99.97
# 4404     99.98
# 4372     99.98
# 4378    100.00
# 4377    100.00
# 4348    100.00
# 4376    100.00
# 4209    100.00
# 1983       NaN
# 6067       NaN
# 6095       NaN
# ...

# %%
oo.NOC.sort_values()
# Out:
# 28965    AFG
# 19323    AHO
# 19874    ALG
# 21960    ALG
# 21610    ALG
# 21946    ALG
# 20200    ALG
# 23624    ALG
# 23890    ALG
# 17064    ALG
# 23536    ALG
# 17060    ALG
# 28602    ALG
# 23631    ALG
# 28637    ALG
# 23655    ALG
# 1154     ANZ
# 1208     ANZ
# 1146     ANZ
# 1648     ANZ
# 1662     ANZ
# 1661     ANZ
# 1660     ANZ
# 1659     ANZ
# 1658     ANZ
# 1656     ANZ
# 1655     ANZ
# 2785     ANZ
# 1654     ANZ
# 1653     ANZ
#         ...
# 865      ZZX
# 767      ZZX
# 768      ZZX
# 136      ZZX
# 494      ZZX
# 424      ZZX
# 425      ZZX
# 426      ZZX
# 427      ZZX
# 428      ZZX
# 429      ZZX
# 261      ZZX
# 260      ZZX
# 259      ZZX
# 258      ZZX
# 430      ZZX
# 431      ZZX
# 257      ZZX
# 432      ZZX
# 433      ZZX
# 137      ZZX
# 769      ZZX
# 422      ZZX
# 135      ZZX
# 134      ZZX
# 133      ZZX
# 493      ZZX
# 132      ZZX
# 495      ZZX
# 864      ZZX
# Name: NOC, Length: 29216, dtype: object

# %%
oo.sort_values(by=['Edition', 'Athlete'])
# Out:
#           City  Edition          Sport       Discipline  \
# 7       Athens     1896       Aquatics         Swimming
# 82      Athens     1896     Gymnastics      Artistic G.
# 110     Athens     1896     Gymnastics      Artistic G.
# 111     Athens     1896     Gymnastics      Artistic G.
# 48      Athens     1896        Cycling     Cycling Road
# 19      Athens     1896      Athletics        Athletics
# 134     Athens     1896         Tennis           Tennis
# 140     Athens     1896         Tennis           Tennis
# 13      Athens     1896      Athletics        Athletics
# 21      Athens     1896      Athletics        Athletics
# 84      Athens     1896     Gymnastics      Artistic G.
# 99      Athens     1896     Gymnastics      Artistic G.
# 66      Athens     1896        Fencing          Fencing
# 4       Athens     1896       Aquatics         Swimming
# 5       Athens     1896       Aquatics         Swimming
# 8       Athens     1896       Aquatics         Swimming
# ...

# %%
oo[(oo.Medal=='Gold') & (oo.Gender=='Women')]
# Out:
#             City  Edition          Sport       Discipline  \
# 417        Paris     1900           Golf             Golf
# 641        Paris     1900         Tennis           Tennis
# 649        Paris     1900         Tennis           Tennis
# 710     St Louis     1904        Archery          Archery
# 713     St Louis     1904        Archery          Archery
# 730     St Louis     1904        Archery          Archery
# 731     St Louis     1904        Archery          Archery
# 732     St Louis     1904        Archery          Archery
# 733     St Louis     1904        Archery          Archery
# 1185      London     1908        Archery          Archery
# 1843      London     1908        Skating   Figure skating
# 1849      London     1908        Skating   Figure skating
# 1870      London     1908         Tennis           Tennis
# 1876      London     1908         Tennis           Tennis
# 1941   Stockholm     1912       Aquatics           Diving
# ...

# %%
oo.Athlete.str.contains('Florence')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 29186    False
# 29187    False
# 29188    False
# 29189    False
# 29190    False
# 29191    False
# 29192    False
# 29193    False
# 29194    False
# 29195    False
# 29196    False
# 29197    False
# 29198    False
# 29199    False
# 29200    False
# 29201    False
# 29202    False
# 29203    False
# 29204    False
# 29205    False
# 29206    False
# 29207    False
# 29208    False
# 29209    False
# 29210    False
# 29211    False
# 29212    False
# ...

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
oo.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %%
oo.index[100]
# Out:
# 100

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# ...

# %%
oo.index
# Out:
# RangeIndex(start=0, stop=29216, step=1)

# %%
oo.index[100]
# Out:
# 100

# %%
oo.index[100] = 'aa'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-edd7a4f33d13> in <module>()
# ----> 1 oo.index[100] = 'aa'
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    1722
#    1723     def __setitem__(self, key, value):
# -> 1724         raise TypeError("Index does not support mutable operations")
#    1725
#    1726     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
oo.set_index('Athlete')
# Out:
#                                 City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto              Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios             Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis            Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon            Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# HAJOS, Alfred                 Athens     1896   Aquatics         Swimming
# ANDREOU, Joannis              Athens     1896   Aquatics         Swimming
# CHOROPHAS, Efstathios         Athens     1896   Aquatics         Swimming
# NEUMANN, Paul                 Athens     1896   Aquatics         Swimming
# PEPANOS, Antonios             Athens     1896   Aquatics         Swimming
# ...

# %%
oo
# Out:
#           City  Edition      Sport       Discipline  \
# 0       Athens     1896   Aquatics         Swimming
# 1       Athens     1896   Aquatics         Swimming
# 2       Athens     1896   Aquatics         Swimming
# 3       Athens     1896   Aquatics         Swimming
# 4       Athens     1896   Aquatics         Swimming
# 5       Athens     1896   Aquatics         Swimming
# 6       Athens     1896   Aquatics         Swimming
# 7       Athens     1896   Aquatics         Swimming
# 8       Athens     1896   Aquatics         Swimming
# 9       Athens     1896   Aquatics         Swimming
# 10      Athens     1896   Aquatics         Swimming
# 11      Athens     1896  Athletics        Athletics
# 12      Athens     1896  Athletics        Athletics
# 13      Athens     1896  Athletics        Athletics
# 14      Athens     1896  Athletics        Athletics
# 15      Athens     1896  Athletics        Athletics
# 16      Athens     1896  Athletics        Athletics
# ...

# %%
oo.set_index('Athlete', inplace=True)

# %%
oo.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo_Ath = oo.set_index('Athlete')

# %%
oo_Ath.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %%
oo_Ath.sort_index(ascending=True,inplace=True)
oo_Ath.head()
# Out:
#                              City  Edition       Sport   Discipline  NOC  \
# Athlete
# AABYE, Edgar                Paris     1900  Tug of War   Tug of War  ZZX
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Arvo Ossian     Antwerp     1920    Aquatics     Swimming  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
# AALTONEN, Paavo Johannes   London     1948  Gymnastics  Artistic G.  FIN
#
#                          Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar                Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian       Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian       Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes    Men   team competition            M    Gold

# %%
oo.loc[[1,4,7]]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
# 7    ANDREOU, Joannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 4  100m freestyle for sailors            M  Silver
# 7             1200m freestyle            M  Silver

# %%
oo.iloc[[1,3]]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 3  100m freestyle for sailors            M    Gold

# %%
gr = oo.groupby('Edition')
gr.size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
el = list(gr)

# %%
type(el[0])
# Out:
# tuple

# %%
for key,value in oo.groupby('Edition'):
    print('Edition :', key)
    print(value)
# Out:
# Edition : 1896
#                          Athlete    City  Edition          Sport  \
# 0                  HAJOS, Alfred  Athens     1896       Aquatics
# 1               HERSCHMANN, Otto  Athens     1896       Aquatics
# 2              DRIVAS, Dimitrios  Athens     1896       Aquatics
# 3             MALOKINIS, Ioannis  Athens     1896       Aquatics
# 4             CHASAPIS, Spiridon  Athens     1896       Aquatics
# 5          CHOROPHAS, Efstathios  Athens     1896       Aquatics
# 6                  HAJOS, Alfred  Athens     1896       Aquatics
# 7               ANDREOU, Joannis  Athens     1896       Aquatics
# 8          CHOROPHAS, Efstathios  Athens     1896       Aquatics
# 9                  NEUMANN, Paul  Athens     1896       Aquatics
# 10             PEPANOS, Antonios  Athens     1896       Aquatics
# 11                 LANE, Francis  Athens     1896      Athletics
# 12              SZOKOLYI, Alajos  Athens     1896      Athletics
# ...

# %%
type(el[0][1])
# Out:
# pandas.core.frame.DataFrame

# %%
gr.size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg(['max', 'min','count'])
# Out:
#                                      Athlete  \
#                                          max
# Edition NOC Medal
# 1896    AUS Gold                FLACK, Edwin
#         AUT Bronze             SCHMAL, Adolf
#             Gold               SCHMAL, Adolf
#             Silver          HERSCHMANN, Otto
#         DEN Bronze           NIELSEN, Holger
#             Gold               JENSEN, Viggo
#             Silver           NIELSEN, Holger
#         FRA Bronze         LERMUSIAUX, Albin
#             Gold                MASSON, Paul
#             Silver        TUFFERI, Alexandre
#         GBR Bronze           GMELIN, Charles
#             Gold         ELLIOTT, Launceston
#             Silver            KEEPING, Frank
#         GER Bronze      WEINGÄRTNER, Hermann
#             Gold        WEINGÄRTNER, Hermann
#             Silver      WEINGÄRTNER, Hermann
#         GRE Bronze          VERSIS, Sotirios
#             Gold            PYRGOS, Leonidas
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold        2
#          AUT  Bronze      2
#               Gold        2
#               Silver      1
#          DEN  Bronze      3
#               Gold        1
#               Silver      2
#          FRA  Bronze      2
#               Gold        5
#               Silver      4
#          GBR  Bronze      2
#               Gold        2
#               Silver      3
#          GER  Bronze      2
#               Gold       26
#               Silver      5
#          GRE  Bronze     22
#               Gold       10
#               Silver     20
#          HUN  Bronze      3
#               Gold        2
#               Silver      1
#          SUI  Gold        1
#               Silver      2
#          USA  Bronze      2
#               Gold       11
#               Silver      7
#          ZZX  Bronze      2
#               Gold        2
#               Silver      2
#                        ...
# 2008     SUI  Gold        3
# ...

# %%
food_info.head()
# Out:
#    NDB_No                 Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001          BUTTER WITH SALT      15.87         717         0.85
# 1    1002  BUTTER WHIPPED WITH SALT      15.87         717         0.85
# 2    1003      BUTTER OIL ANHYDROUS       0.24         876         0.28
# 3    1004               CHEESE BLUE      42.41         353        21.40
# 4    1005              CHEESE BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Vit_A_IU  Vit_A_RAE  Vit_E_(mg)  Vit_D_mcg  Vit_D_IU  \
# ...

# %%
food_info.groupby(['Water_(g)','Protein_(g)','Water_(g)']).agg(['max','min','count'])
# Out:
#                                 NDB_No               \
#                                    max    min count
# Water_(g) Protein_(g) Water_(g)
# 0.00      0.00        0.00       44005   4001    96
# 0.02      0.00        0.02       19335  19335     1
#           0.56        0.02       35057  35057     1
# 0.03      0.00        0.03       19908  19908     1
# 0.04      0.00        0.04        4662   4658     3
# 0.05      0.00        0.05        4657   4656     2
# 0.07      0.00        0.07        4661   4661     1
# 0.08      0.00        0.08        4663   4659     2
# 0.11      0.26        0.11        4679   4679     1
# 0.12      0.11        0.12       42231  42231     1
# 0.13      0.12        0.13       14370  14357     2
# 0.14      0.00        0.14       14407  14407     1
# 0.16      0.37        0.16        4707   4707     1
# 0.18      6.41        0.18       19914  19914     1
# 0.20      0.00        0.20       18372   2047     7
# ...

# %%
oo.loc[oo.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['max','min','count']})
# Out:
#             Edition
#                 max   min count
# Athlete
# LEWIS, Carl    1996  1984    10

# %%
mw = oo[(oo.Edition==2008)&((oo.Event=='100m')|(oo.Event=='200m'))]
mw.head()
# Out:
#                   Athlete     City  Edition      Sport Discipline  NOC Gender  \
# 27551         DIX, Walter  Beijing     2008  Athletics  Athletics  USA    Men
# 27552         BOLT, Usain  Beijing     2008  Athletics  Athletics  JAM    Men
# 27553   THOMPSON, Richard  Beijing     2008  Athletics  Athletics  TRI    Men
# 27554  FRASER, Shelly-ann  Beijing     2008  Athletics  Athletics  JAM  Women
# 27555    SIMPSON, Sherone  Beijing     2008  Athletics  Athletics  JAM  Women
#
#       Event Event_gender   Medal
# 27551  100m            M  Bronze
# 27552  100m            M    Gold
# 27553  100m            M  Silver
# 27554  100m            W    Gold
# 27555  100m            W  Silver

# %%
mw = oo[(oo.Edition==2008)&((oo.Event=='100m')|(oo.Event=='200m'))]
g = mw.groupby(['NOC', 'Gender', 'Discipline', 'Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df = g.unstack(['Gender','Discipline', 'Event'])
df
# Out:
# Gender           Men          Women
# Discipline Athletics      Athletics
# Event           100m 200m      100m 200m
# NOC
# JAM              1.0  1.0       3.0  2.0
# TRI              1.0  NaN       NaN  NaN
# USA              1.0  2.0       NaN  1.0

# %%
df.stack('Event')
# Out:
# Gender           Men     Women
# Discipline Athletics Athletics
# NOC Event
# JAM 100m         1.0       3.0
#     200m         1.0       2.0
# TRI 100m         1.0       NaN
# USA 100m         1.0       NaN
#     200m         2.0       1.0

# %%
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
df.unstack('Gender')
# Out:
# Discipline Athletics
# Event           100m       200m
# Gender           Men Women  Men Women
# NOC
# JAM              1.0   3.0  1.0   2.0
# TRI              1.0   NaN  NaN   NaN
# USA              1.0   NaN  2.0   1.0

# %%
lo = oo[oo.Edition==2008]
lo.head()
# Out:
#                 Athlete     City  Edition     Sport Discipline  NOC Gender  \
# 27174    GALPERIN, Gleb  Beijing     2008  Aquatics     Diving  RUS    Men
# 27175  MITCHAM, Matthew  Beijing     2008  Aquatics     Diving  AUS    Men
# 27176       ZHOU, Luxin  Beijing     2008  Aquatics     Diving  CHN    Men
# 27177         WANG, Xin  Beijing     2008  Aquatics     Diving  CHN  Women
# 27178      CHEN, Ruolin  Beijing     2008  Aquatics     Diving  CHN  Women
#
#               Event Event_gender   Medal
# 27174  10m platform            M  Bronze
# 27175  10m platform            M    Gold
# 27176  10m platform            M  Silver
# 27177  10m platform            W  Bronze
# 27178  10m platform            W    Gold

# %%
g = oo[oo.Edition==2008].groupby(['NOC','Medal']).size()
g = g.unstack('Medal', fill_value=0)
g
# Out:
# Medal  Bronze  Gold  Silver
# NOC
# AFG         1     0       0
# ALG         1     0       1
# ARG        31    20       0
# ARM         6     0       0
# AUS        76    31      42
# AUT         2     0       1
# AZE         4     1       2
# BAH         1     0       4
# BEL         0     1       4
# BLR        17     8       5
# BRA        27    14      34
# BUL         3     1       1
# CAN        10    11      13
# CHI         0     0       1
# CHN        57    74      53
# CMR         0     1       0
# COL         1     0       1
# CRO         3     0       2
# CUB        11     2      34
# CZE         0     3       4
# DEN         6     6       6
# DOM         0     1       1
# ECU         0     0       1
# EGY         1     0       0
# ESP        16     7      48
# EST         0     1       2
# ETH         2     4       1
# FIN         2     1       2
# FRA        28    25      23
# GBR        21    31      25
# ..        ...   ...     ...
# NGR         6     0      18
# ...

# %%
g = oo[oo.Edition==2008].groupby(['NOC','Medal']).size()
g = g.unstack('Medal', fill_value=0)
g = g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
g
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# NED      40      18       4
# AUS      31      42      76
# GBR      31      25      21
# FRA      25      23      28
# JPN      23      11      17
# ARG      20       0      31
# HUN      16       8       3
# NOR      16       5       1
# BRA      14      34      27
# CAN      11      13      10
# UKR      10       5      16
# JAM       9       3       5
# ITA       8      14      20
# BLR       8       5      17
# ESP       7      48      16
# POL       6      13       1
# DEN       6       6       6
# KEN       6       4       4
# ROU       5       1      16
# SVK       4       5       1
# NZL       4       2       8
# ETH       4       1       2
# CZE       3       4       0
# SUI       3       0       8
# GEO       3       0       3
# ..      ...     ...     ...
# SWE       0       5       2
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(g)

# %%
g = oo[oo.Edition==2008].groupby(['NOC','Medal']).size()
g = g.unstack('Medal', fill_value=0)  # fill_value=0将数据集中空值设为0
g = g.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
g = g.transpose()   # 转置
g
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN ...   VIE  ARM  TPE  \
# Medal                                                    ...
# Gold    125   74   43   42   41   40   31   31   25   23 ...     0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11 ...     1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17 ...     0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,5))
sns.heatmap(g)

# %%
oo.Athlete.apply(str.lower).head()
# Out:
# 0         hajos, alfred
# 1      herschmann, otto
# 2     drivas, dimitrios
# 3    malokinis, ioannis
# 4    chasapis, spiridon
# Name: Athlete, dtype: object

# %%
def to_upper(x):
    return str.upper(x)

# %%
oo.Athlete.apply(to_upper).head()
# Out:
# 0         HAJOS, ALFRED
# 1      HERSCHMANN, OTTO
# 2     DRIVAS, DIMITRIOS
# 3    MALOKINIS, IOANNIS
# 4    CHASAPIS, SPIRIDON
# Name: Athlete, dtype: object

# %%
oo.head()
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# 4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[1:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
oo[:4]
# Out:
#               Athlete    City  Edition     Sport Discipline  NOC Gender  \
# 0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming  HUN    Men
# 1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming  AUT    Men
# 2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming  GRE    Men
# 3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold

# %%
df = pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0  1.523125 -0.921855  1.127533 -0.049479
# 1  1.351944  0.272416  0.761144  0.385504
# 2  1.360067  0.730057  0.995401 -0.314437
# 3 -1.330648 -0.508185  1.720260 -0.087951
# 4 -0.538221  1.300799 -0.384892  0.347298
# 5  0.109737 -0.270088  0.494393  0.282641
# 6  2.008395  1.465773  0.284843 -0.503224
# 7 -1.055475 -0.114002  1.488978  0.374149
# 8 -2.544028 -0.290559  1.134260  1.474558
# 9 -0.540832 -0.082792  0.037751 -0.003658

# %%
df1 = df[:3]
df1
# Out:
#           0         1         2         3
# 0  1.523125 -0.921855  1.127533 -0.049479
# 1  1.351944  0.272416  0.761144  0.385504
# 2  1.360067  0.730057  0.995401 -0.314437

# %%
df2 = df[3:5]
df2
# Out:
#           0         1         2         3
# 3 -1.330648 -0.508185  1.720260 -0.087951
# 4 -0.538221  1.300799 -0.384892  0.347298

# %%
mg = pd.concat([df1,df2])
mg
# Out:
#           0         1         2         3
# 0  1.523125 -0.921855  1.127533 -0.049479
# 1  1.351944  0.272416  0.761144  0.385504
# 2  1.360067  0.730057  0.995401 -0.314437
# 3 -1.330648 -0.508185  1.720260 -0.087951
# 4 -0.538221  1.300799 -0.384892  0.347298

# %%
noc = pd.read_csv('Olympic2.csv',skiprows=4)
del noc['American Samoa*.1']
noc.head(2)
# Out:
#   American Samoa*  ASA  AS
# 0         Andorra  AND  AD
# 1          Angola  ANG  AO

# %%
m3 = pd.merge(oo, noc, left_on='NOC', right_on='ASA')
m3.head(3)
# Out:
#             Athlete    City  Edition      Sport Discipline  NOC Gender  \
# 0     HAJOS, Alfred  Athens     1896   Aquatics   Swimming  HUN    Men
# 1     HAJOS, Alfred  Athens     1896   Aquatics   Swimming  HUN    Men
# 2  SZOKOLYI, Alajos  Athens     1896  Athletics  Athletics  HUN    Men
#
#              Event Event_gender   Medal American Samoa*  ASA  AS
# 0   100m freestyle            M    Gold         Hungary  HUN  HU
# 1  1200m freestyle            M    Gold         Hungary  HUN  HU
# 2             100m            M  Bronze         Hungary  HUN  HU

# %%
m4 = pd.merge(oo, noc, left_on='NOC', right_on='ASA', how='right')
m4.tail(2)
# Out:
#       Athlete City  Edition Sport Discipline  NOC Gender Event Event_gender  \
# 23916     NaN  NaN      NaN   NaN        NaN  NaN    NaN   NaN          NaN
# 23917     NaN  NaN      NaN   NaN        NaN  NaN    NaN   NaN          NaN
#
#       Medal American Samoa*  ASA  AS
# 23916   NaN         Vanuatu  VAN  VU
# 23917   NaN           Yemen  YEM  YE

# %%
noc = noc.rename(index=str, columns={'ASA':'NOC'})
noc.head(2)
# Out:
#   American Samoa*  NOC  AS
# 0         Andorra  AND  AD
# 1          Angola  ANG  AO

# %%
m5 = pd.merge(oo, noc, on='NOC')
m5.tail(3)
# Out:
#                   Athlete     City  Edition          Sport       Discipline  \
# 23839  BOUKPETI, Benjamin  Beijing     2008  Canoe / Kayak  Canoe / Kayak S
# 23840       BOQIEV, Rasul  Beijing     2008           Judo             Judo
# 23841  ABDUSALOMOV, Yusup  Beijing     2008      Wrestling  Wrestling Free.
#
#        NOC Gender                    Event Event_gender   Medal  \
# 23839  TOG    Men       K-1 (kayak single)            M  Bronze
# 23840  TJK    Men  66 - 73kg (lightweight)            M  Bronze
# 23841  TJK    Men                74 - 84kg            M  Silver
#
#       American Samoa*  AS
# 23839            Togo  TG
# 23840      Tajikistan  TJ
# 23841      Tajikistan  TJ

# %%
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x + i*.5) * (7 - i) * flip)

# %%
sinplot()

# %%
sns.set()
sinplot()

# %% [markdown]
# 共有五种主题风格：
#     white，
#     dark,
#     darkgrid,
#     whitegrid,
#     ticks

# %%
sns.set_style('whitegrid') # style 五种：white，dark,darkgrid,ticks
data = np.random.normal(size=(20,6)) + np.arange(6)/2
sns.boxplot(data=data)

# %%
sns.set_style('ticks')
sinplot()
sns.despine()

# %%
sns.set_style('darkgrid')
sns.violinplot(data)
sns.despine(offset=10)

# %%
sns.set_style('whitegrid')
sns.boxplot(data=data,palette='deep')
sns.despine(left=True)

# %%
with sns.axes_style('darkgrid'):
    plt.subplot(211)
    sinplot()
plt.subplot(212)
sinplot(-1)

# %%
sns.set()

# %%
sns.set_context('paper')
plt.figure(figsize=(8,6))
sinplot()

# %%
sns.set_context('talk')
plt.figure(figsize=(8,6))
sinplot()

# %%
sns.set_context('poster')
plt.figure(figsize=(8,6))
sinplot()

# %%
sns.set_context('notebook', font_scale=1.5, rc={'lines.linewidth':3.5})
plt.figure(figsize=(8,6))
sinplot()

# %%
sns.set(rc={'figure.figsize':(8,6)})

# %% [markdown]
# color_palette()
# set_palette()设置所有图的颜色

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %% [markdown]
# 颜色循环主题：deep,muted,pastel,bright,dark,colorblind

# %%
sns.palplot(sns.color_palette('hls', 10))

# %%
data = np.random.normal(size=(20,8)) + np.arange(8)/2
sns.boxplot(data=data, palette=sns.color_palette('hls', 8))

# %%
sns.palplot(sns.hls_palette(8, l=0.7, s=0.5))

# %%
sns.palplot(sns.color_palette('Paired', 8)) # Paired表示调出的颜色时一对一对的

# %%
sns.palplot(sns.color_palette('Blues'))

# %% [markdown]
# 如果想要翻转颜色渐变，可在面板名称后加_r后缀

# %%
sns.palplot(sns.color_palette('Blues_r'))

# %%
sns.palplot(sns.color_palette('cubehelix', 8))

# %%
sns.palplot(sns.cubehelix_palette(8, start=0.5, rot=-0.75))

# %%
sns.palplot(sns.cubehelix_palette(8, start=0.75, rot=-0.15))

# %%
sns.palplot(sns.light_palette('green'))

# %%
sns.palplot(sns.light_palette('yellow', reverse= True))

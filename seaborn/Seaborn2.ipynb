# %%
import seaborn as sns
import numpy as np
import pandas as pd
from scipy import stats, integrate
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set(color_codes=True)
np.random.seed(sum(map(ord,'distributions')))

# %%
x = np.random.normal(size=100)
sns.distplot(x, kde=False)

# %%
sns.distplot(x, bins=20, kde=False)

# %%
x = np.random.gamma(6, size=200)
sns.distplot(x, kde=False, fit=stats.gamma)

# %%
r = stats.gamma.rvs(1.99, size=1000)
plt.hist(r, normed=True, histtype='stepfilled', alpha=0.2)
# Out:
# (array([0.27581851, 0.33281421, 0.20966278, 0.10992029, 0.04580012,
#         0.02442673, 0.01119559, 0.00407112, 0.00101778, 0.00305334]),
#  array([0.03643006, 1.0189602 , 2.00149035, 2.9840205 , 3.96655065,
#         4.9490808 , 5.93161095, 6.9141411 , 7.89667125, 8.8792014 ,
#         9.86173155]),
#  <a list of 1 Patch objects>)

# %%
mean, cov = [0,1], [(1,.5),(.5,1)]
data = np.random.multivariate_normal(mean, cov, 200)
df = pd.DataFrame(data, columns=['x','y'])
df
# Out:
#             x         y
# 0    0.350739  0.976414
# 1   -0.402779 -0.305869
# 2    0.838747  2.650283
# 3    0.077909  1.275857
# 4    1.497997  1.319545
# 5   -0.074845 -0.305165
# 6   -1.568518  0.356586
# 7    1.843279  1.708958
# 8    0.127139  0.627665
# 9   -0.831119  0.270233
# 10   0.515759  2.061762
# 11  -0.558467  1.982549
# 12   0.565106  0.519503
# 13  -0.532790  0.321984
# 14  -0.848433  0.134734
# 15  -1.972271 -0.988314
# 16  -0.148509  3.352139
# 17  -0.417198  0.672167
# 18  -0.816050  0.795260
# 19  -3.042031  0.077816
# 20  -0.217647  0.394529
# 21  -0.384123  0.908997
# 22  -0.091826  1.201946
# 23  -2.233606  0.688360
# 24   1.487225  3.451382
# 25  -0.550921 -0.923087
# 26  -0.019658  0.379973
# 27   1.279155  0.931238
# 28  -0.841514  0.711172
# 29  -0.341331  0.465284
# ..        ...       ...
# 170 -1.263321 -0.885236
# 171  0.188130  2.057918
# 172  1.345536  1.158115
# 173  1.294485  1.461321
# 174 -0.068247  0.887662
# 175 -0.073805  2.436425
# ...

# %%
sns.jointplot(x='x',y='y',data=df)

# %%
x,y = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style('white'):
    sns.jointplot(x=x,y=y,kind='hex', color='b')

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
from scipy.stats import spearmanr
data = np.random.multivariate_normal(mean, cov, 1000).T
with sns.axes_style('white'):
    sns.jointplot("size", "total_bill",data=tips,stat_func=spearmanr, color='b')

# %%
iris = sns.load_dataset('iris')
sns.pairplot(iris)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='size',y='tip',data=tips)

# %%
sns.lmplot(x='size',y='tip',data=tips, x_jitter=0.05)

# %%
titanic = sns.load_dataset('titanic')
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')

# %%
sns.stripplot('day', 'total_bill', data=tips)

# %%
sns.stripplot('day', 'total_bill', data=tips, jitter=True)

# %%
sns.swarmplot('day', 'total_bill', data=tips)

# %%
sns.swarmplot( 'total_bill','day', data=tips, hue='time')

# %%
sns.boxplot( 'day', 'total_bill', data=tips, hue='time')

# %%
sns.violinplot( 'day', 'total_bill', data=tips, hue='time')

# %%
sns.violinplot( 'day', 'total_bill', data=tips, hue='sex', split=True)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.violinplot( 'day', 'total_bill', data=tips, hue='sex', split=True, inner="stick", palette="Set3")

# %%
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
sns.swarmplot(x="day", y="total_bill", data=tips, color="w", alpha=.5);

# %%
sns.barplot(x="sex", y="survived", hue="class", data=titanic);

# %%
sns.pointplot(x="sex", y="survived", hue="class", data=titanic);

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 0           0       3    male  22.0      1      0    7.2500        S   Third
# 1           1       1  female  38.0      1      0   71.2833        C   First
# 2           1       3  female  26.0      0      0    7.9250        S   Third
# 3           1       1  female  35.0      1      0   53.1000        S   First
# 4           0       3    male  35.0      0      0    8.0500        S   Third
# 5           0       3    male   NaN      0      0    8.4583        Q   Third
# 6           0       1    male  54.0      0      0   51.8625        S   First
# 7           0       3    male   2.0      3      1   21.0750        S   Third
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 9           1       2  female  14.0      1      0   30.0708        C  Second
# 10          1       3  female   4.0      1      1   16.7000        S   Third
# ...

# %%
sns.distplot(titanic.survived, kde=False, fit=stats.gamma);

# %%
age = titanic.age.fillna(-20)

# %%
age.value_counts()
# Out:
# -20.00    177
#  24.00     30
#  22.00     27
#  18.00     26
#  28.00     25
#  19.00     25
#  30.00     25
#  21.00     24
#  25.00     23
#  36.00     22
#  29.00     20
#  32.00     18
#  26.00     18
#  35.00     18
#  27.00     18
#  16.00     17
#  31.00     17
#  34.00     15
#  23.00     15
#  33.00     15
#  20.00     15
#  39.00     14
#  17.00     13
#  42.00     13
#  40.00     13
#  45.00     12
#  38.00     11
#  50.00     10
#  2.00      10
#  4.00      10
#          ...
#  28.50      2
#  63.00      2
#  0.83       2
#  30.50      2
#  70.00      2
#  57.00      2
#  0.75       2
#  13.00      2
#  59.00      2
#  10.00      2
#  64.00      2
#  40.50      2
#  45.50      2
#  32.50      2
#  20.50      1
#  24.50      1
#  0.67       1
#  70.50      1
#  0.92       1
#  74.00      1
#  34.50      1
#  14.50      1
#  80.00      1
#  12.00      1
#  53.00      1
#  36.50      1
#  55.50      1
#  66.00      1
#  23.50      1
#  0.42       1
# ...

# %%
sns.distplot(age)

# %% [markdown]
# <font face='黑体' size=5 >markers可选：x,o,v,^,< </font>

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic,
              palette={"male": "g", "female": "m"},
              markers=["<", "o"], linestyles=["-", "--"])

# %% [markdown]
# <font face='黑体' size=5 >多层面板分类图</font>

# %%
sns.boxplot(data=iris, orient="h");

# %%
sns.factorplot('day','total_bill', hue='smoker', data=tips)

# %%
sns.factorplot('day','total_bill', hue='smoker', data=tips, kind='bar')

# %%
sns.factorplot('day','total_bill', hue='smoker', col='time', 
               data=tips, kind='swarm')

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
               col="day", data=tips, kind="violin", size=4, aspect=.5)

# %%
sns.factorplot(x="time", y="total_bill", hue="smoker",
            data=tips, kind="strip", size=4, aspect=.5)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(tips, col='time')

# %%
g = sns.FacetGrid(tips, col='time')
g.map(plt.hist, 'tip')

# %%
g = sns.FacetGrid(tips, col='sex', hue='smoker')
g.map(plt.scatter, 'tip', 'total_bill', alpha=.7)
g.add_legend()

# %%
g = sns.FacetGrid(tips, col='day', size=4, aspect=.5)
g.map(sns.barplot, 'sex', 'total_bill', alpha=.7)
# Out:
# /usr/local/lib/python3.5/dist-packages/seaborn/axisgrid.py:703: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
from pandas import Categorical
ordered_days = tips.day.value_counts().index
print(ordered_days)
ordered_days = Categorical(['Thur','Fri','Sat','Sun'])
g = sns.FacetGrid(tips, row='day', row_order=ordered_days,
                 size=1.5, aspect=4)
g.map(sns.boxplot, 'total_bill')
# Out:
# CategoricalIndex(['Sat', 'Sun', 'Thur', 'Fri'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, dtype='category')
# /usr/local/lib/python3.5/dist-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
pal = dict(Lunch="seagreen", Dinner="gray")
g = sns.FacetGrid(tips, hue="time", palette=pal, size=5)
g.map(plt.scatter, "total_bill", "tip", s=50, alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend();

# %%
g = sns.FacetGrid(tips, hue="sex", palette="Set1", size=5, hue_kws={'marker': ["^", "v"]} )
g.map(plt.scatter, "total_bill", "tip", s=100, linewidth=.5, edgecolor="white")
g.add_legend();

# %%
np.random.seed(2)
uniform_data  = np.random.rand(10,13)
# print(uniform_data)
heatmap = sns.heatmap(uniform_data)

# %%
ax = sns.heatmap(uniform_data, vmin=0.25, vmax=0.4)

# %%
flights = sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)

# %%
ax = sns.heatmap(flights, annot=True, fmt="d")

# %%
ax = sns.heatmap(flights, cmap='YlGnBu')
